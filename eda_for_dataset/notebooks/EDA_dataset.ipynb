# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### READING DATA

# %%
df = pd.read_csv(r'/content/drive/MyDrive/bean_disease_project/EDA_for_dataset/bean_csv_dataset/raw_dataset.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#         folder    name           filename  ... name18    ymax name19
# 0  bean_rust_1  folder  1619076319672.jpg  ...   xmax  1757.0   ymax
# 1  bean_rust_1  folder  1619076319672.jpg  ...   xmax  1310.0   ymax
# 2  bean_rust_1  folder  1619076319672.jpg  ...   xmax  1875.0   ymax
# 3  bean_rust_1  folder  1619076319672.jpg  ...   xmax  3013.0   ymax
# 4  bean_rust_1  folder  1619076319672.jpg  ...   xmax  2212.0   ymax
#
# [5 rows x 36 columns]

# %%
df.tail()
# Out:
#       folder    name           filename     name2  ...    xmax name18   ymax name19
# 36652  als_1  folder  1621935335739.jpg  filename  ...   700.0   xmax  846.0   ymax
# 36653  als_1  folder  1621932326095.jpg  filename  ...   338.0   xmax  804.0   ymax
# 36654  als_1  folder  1621844666065.jpg  filename  ...   496.0   xmax  986.0   ymax
# 36655  als_1  folder  1621844666065.jpg  filename  ...   822.0   xmax  696.0   ymax
# 36656  als_1  folder  1621844666065.jpg  filename  ...  1014.0   xmax  987.0   ymax
#
# [5 rows x 36 columns]

# %%
df.describe(include='all')
# Out:
#              folder    name           filename  ... name18          ymax name19
# count         36657   36657              36657  ...  36640  36640.000000  36640
# unique            4       1              10118  ...      1           NaN      1
# top     bean_rust_2  folder  1619245388614.jpg  ...   xmax           NaN   ymax
# freq           9688   36657                 16  ...  36640           NaN  36640
# mean            NaN     NaN                NaN  ...    NaN    664.500710    NaN
# std             NaN     NaN                NaN  ...    NaN    377.704111    NaN
# min             NaN     NaN                NaN  ...    NaN     24.000000    NaN
# 25%             NaN     NaN                NaN  ...    NaN    434.000000    NaN
# 50%             NaN     NaN                NaN  ...    NaN    617.000000    NaN
# 75%             NaN     NaN                NaN  ...    NaN    822.000000    NaN
# max             NaN     NaN                NaN  ...    NaN   4275.000000    NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# folder                0
# name                  0
# filename              0
# name2                 0
# path                  0
# name3                 0
# width                 0
# name4                 0
# height                0
# name5                 0
# depth                 0
# name6                 0
# class                 0
# name7                 0
# hasOtherSymptoms      0
# name8                 0
# variety               0
# name9                 0
# age                   0
# name10                0
# district              0
# name11                0
# subcounty           156
# name12                0
# datetime              0
# name13                0
# name14               17
# name15               17
# xmin                 17
# name16               17
# ymin                 17
# name17               17
# xmax                 17
# name18               17
# ymax                 17
# name19               17
# dtype: int64

# %% [markdown]
# CLEANING DATASET

# %%
dataset=df.drop(['name','name2','name3','name4','name5','name6','name7','name8','name9','name10','name11','name12','name13','name14','name15','name16','name17','name18','name19'],axis=1)

# %%
dataset=df.drop(['name2'],axis=1)

# %%
dataset.head()
# Out:
#         folder           filename  ...    xmax    ymax
# 0  bean_rust_1  1619076319672.jpg  ...   898.0  1757.0
# 1  bean_rust_1  1619076319672.jpg  ...  1302.0  1310.0
# 2  bean_rust_1  1619076319672.jpg  ...  1682.0  1875.0
# 3  bean_rust_1  1619076319672.jpg  ...   727.0  3013.0
# 4  bean_rust_1  1619076319672.jpg  ...  1004.0  2212.0
#
# [5 rows x 17 columns]

# %%
dataset.isnull().sum()
# Out:
# folder                0
# filename              0
# path                  0
# width                 0
# height                0
# depth                 0
# class                 0
# hasOtherSymptoms      0
# variety               0
# age                   0
# district              0
# subcounty           156
# datetime              0
# xmin                 17
# ymin                 17
# xmax                 17
# ymax                 17
# dtype: int64

# %% [markdown]
# RELATING DATASET

# %%
corelation=dataset.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns,annot=True)

# %%
sns.pairplot(dataset)

# %%
sns.relplot(x='xmin',y='ymin',hue='district',data=dataset)

# %%
sns.relplot(x='xmax',y='ymax',hue='district',data=dataset)

# %%
sns.distplot(df['xmin'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['ymax'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
