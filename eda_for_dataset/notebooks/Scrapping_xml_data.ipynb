# %% [markdown]
# ## **Import** **Modules**

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

# %%
folder_path = "/content/drive/MyDrive/bean_disease_project/dataset"
list_of_files = os.listdir(folder_path)

# %%
import os
 
directory = '/content/drive/MyDrive/bean_disease_project/dataset'
 
xml_files = []
for root, dirs, files in os.walk(directory):
    for file in files:
        if file.endswith('.xml'):
            print(os.path.join(root, file))
            xml_files.append(file)
            print(file)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/bean_disease_project/dataset/als_1/1619084179435.xml
# 1619084179435.xml
# /content/drive/MyDrive/bean_disease_project/dataset/als_1/1619252463787.xml
# 1619252463787.xml
# /content/drive/MyDrive/bean_disease_project/dataset/als_1/1621598657957.xml
# 1621598657957.xml
# /content/drive/MyDrive/bean_disease_project/dataset/als_1/1621837465801.xml
# 1621837465801.xml
# /content/drive/MyDrive/bean_disease_project/dataset/als_1/1621587963575.xml
# 1621587963575.xml
# /content/drive/MyDrive/bean_disease_project/dataset/als_1/1621836527007.xml
# 1621836527007.xml
# /content/drive/MyDrive/bean_disease_project/dataset/als_1/1621839520716.xml
# 1621839520716.xml
# /content/drive/MyDrive/bean_disease_project/dataset/als_1/1621759488055.xml
# 1621759488055.xml
# /content/drive/MyDrive/bean_disease_project/dataset/als_1/1619350722942.xml
# 1619350722942.xml
# ...

# %%
print(xml_files)
# Out:
# ['1619076319672.xml', '1619076429603.xml', '1619076591536.xml', '1619076592706.xml', '1619076628894.xml', '1619076793839.xml', '1619077058449.xml', '1619077095853.xml', '1619076708925.xml', '1619077117030.xml', '1619077179744.xml', '1619077222602.xml', '1619077184045.xml', '1619077236582.xml', '1619244450422.xml', '1619077272513.xml', '1619244551495.xml', '1619244564306.xml', '1619244583162.xml', '1619244631387.xml', '1619244716042.xml', '1619244642710.xml', '1619244641335.xml', '1619244731569.xml', '1619244755478.xml', '1619244785446.xml', '1619244826213.xml', '1619244838612.xml', '1619244868031.xml', '1619244938255.xml', '1619244957927.xml', '1619244974927.xml', '1619244943883.xml', '1619245033457.xml', '1619245042897.xml', '1619245094376.xml', '1619245093864.xml', '1619245072760.xml', '1619245101525.xml', '1619245106553.xml', '1619245112141.xml', '1619245117809.xml', '1619245119172.xml', '1619245119673.xml', '1619245125865.xml', '1619245141189.xml', '1619245168353.xml', '161924516
# ...

# %%
print(len(xml_files))
# Out:
# 10118

# %%
xml_files[0]
a_file = open(xml_files[0])

file_contents = a_file.read()

print(file_contents)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-214bde9074ee> in <module>()
#       1 xml_files[0]
# ----> 2 a_file = open(xml_files[0])
#       3
#       4 file_contents = a_file.read()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '1619076319672.xml'

# %%
xml_file_path = []
for root, dirs, files in os.walk(directory):
    for file in files:
        if file.endswith('.xml'):
            print(os.path.join(root, file))
            xml_file_path.append(os.path.join(root, file))
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/bean_disease_project/dataset/bean_rust_2/1619244955646.xml
# /content/drive/MyDrive/bean_disease_project/dataset/bean_rust_2/1619245213243.xml
# /content/drive/MyDrive/bean_disease_project/dataset/bean_rust_2/1619245312546.xml
# /content/drive/MyDrive/bean_disease_project/dataset/bean_rust_2/1619245236220.xml
# /content/drive/MyDrive/bean_disease_project/dataset/bean_rust_2/1619245345407.xml
# /content/drive/MyDrive/bean_disease_project/dataset/bean_rust_2/1619245355340.xml
# /content/drive/MyDrive/bean_disease_project/dataset/bean_rust_2/1619245468742.xml
# /content/drive/MyDrive/bean_disease_project/dataset/bean_rust_2/1619245586419.xml
# /content/drive/MyDrive/bean_disease_project/dataset/bean_rust_2/1619245810432.xml
# /content/drive/MyDrive/bean_disease_project/dataset/bean_rust_2/1619245843094.xml
# /content/drive/MyDrive/bean_disease_project/dataset/bean_rust_2/1619245920518.xml
# ...

# %%
len(xml_file_path)
# Out:
# 10118

# %%
xml_file_path[0]
a_file = open(xml_file_path[0])

file_contents = a_file.read()

print(file_contents)
# Out:
# <annotation><folder name="folder">bean_rust_1</folder><filename name="filename">1619076319672.jpg</filename><path name="path">beans/bean_rust_1/1619076319672.jpg</path><size><width name="width">2000</width><height name="height">3200</height><depth name="depth">3</depth></size><class name="class">Bean Rust</class><hasOtherSymptoms name="has other symptoms">False</hasOtherSymptoms><variety name="variety">Nambale short</variety><age name="age">7</age><district name="district">Mubende</district><subcounty name="subcounty">Kasambya</subcounty><datetime name="datetime">2021-04-22T10:28:00.475+03:00</datetime><object><name name="name">Bean Rust</name><bndbox><xmin name="xmin">260</xmin><ymin name="ymin">1384</ymin><xmax name="xmax">898</xmax><ymax name="ymax">1757</ymax></bndbox></object><object><name name="name">Bean Rust</name><bndbox><xmin name="xmin">1020</xmin><ymin name="ymin">1167</ymin><xmax name="xmax">1302</xmax><ymax name="ymax">1310</ymax></bndbox></object><object><name name="na
# ...

# %%
for i in xml_file_path:
  a_file = open(i)

  file_contents = a_file.read()

  print(file_contents)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
for i in range(4000):
  a_file = open(xml_file_path[i])

  file_contents = a_file.read()

  print(file_contents)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
for i in range(4000,8000):
  a_file = open(xml_file_path[i])

  file_contents = a_file.read()

  print(file_contents)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
for i in range(8000,10118):
  a_file = open(xml_file_path[i])

  file_contents = a_file.read()

  print(file_contents)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
